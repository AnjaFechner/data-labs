# %% [markdown]
# 1a. Task: Create a link to an article with the content of ethical issues with computer visin applications

# %% [markdown]
# [To what extent does Computer Vision AI need ethics?](https://medium.com/dain-studios/to-what-extent-does-computer-vision-ai-need-ethics-84c0816f565)

# %% [markdown]
# 1b. Task: What is my opinion?

# %% [markdown]
# - For example, AI will help us to improve processes im companies and increase the productivity of the employees. That is a big advantages for now and the future. The number of employees will decrease due to retirement. The amount of work and the complexity of work increases so the employees that remains in the work area needs help to handle the increase in work and complexitiy. In this case, the AI could be the supporter of the employees, decision makers and customers. The best goal is a win-win-situation for all.
#
# - But not all aims are complementary. Some goals are mutually exclusive. That is valid for different areas of the whole life, not only for the working part. The AI needs framework. Because the code of an AI depends on the people who coded and the aim why the AI will produce. And only a small group of people can influenced the AI. On the other hand the society of a country consists of many different groups. The AI have to be construct under consideration of the different groups that are confrotonted with the AI. Disadvantges have to be avoid.
#
# - An AI filtered and the resaults could be nice for the company or the initiator of the AI but they will lose information or people (e.g. AI as a part of a hiring process). And nobody will know if the loss is a "win" or is the loss a big loss at the current time. That impact not only a company that results impact all "users" of the AI. The ethical part can used to minimize the big loss or to eliminate the big loss. To achieva that, a regular chekcing and development must be an obligation.

# %% [markdown]
# 2a. Choose a image and dsiplay this in the jupyter notebook.

# %%
# use the libraries
# %matplotlib inline
from IPython.display import Image
Image('your_image.png')

# %% [markdown]
# 2b. Evaluation of how good a job the machine has done.

# %% [markdown]
# - I chose the category "home office". The picture fits the category. The machine did a good job.
#
# - It is interesting to check whether the machine also selects the correct picture for this category if the pictures show not only screens but also televisions. But maybe there is an algorithm that checks the size of the "screen" and makes an additional assignment. At the moment I do not know, how detailed the machinecan learn.
