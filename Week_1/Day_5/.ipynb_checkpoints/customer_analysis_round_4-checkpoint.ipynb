# %% [markdown]
# ### Start work: Import Labaries

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### 1. Show the dataframe shape.

# %%
file1 = pd.read_csv('marketing_customer_analysis.csv')

# %%
file1.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
# 2           2/19/11         Employed      F   48767      Suburban
# 3           1/20/11       Unemployed      M       0      Suburban
# 4            2/3/11         Employed      M   43836         Rural
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# ...

# %%
file1.shape
# Out:
# (9134, 24)

# %% [markdown]
# ### 2. Standardize header names.

# %%
file1.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
len(file1.columns)
# Out:
# 24

# %%
new_columns = []

for i in range(len(file1.columns)):
# Important: replace -> The space between the first " "
    new_columns.append(file1.columns[i].lower().replace(" ","_"))
new_columns
# Out:
# ['customer',
#  'state',
#  'customer_lifetime_value',
#  'response',
#  'coverage',
#  'education',
#  'effective_to_date',
#  'employmentstatus',
#  'gender',
#  'income',
#  'location_code',
#  'marital_status',
#  'monthly_premium_auto',
#  'months_since_last_claim',
#  'months_since_policy_inception',
#  'number_of_open_complaints',
#  'number_of_policies',
#  'policy_type',
#  'policy',
#  'renew_offer_type',
#  'sales_channel',
#  'total_claim_amount',
#  'vehicle_class',
#  'vehicle_size']

# %%
file1.columns = new_columns
file1.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %% [markdown]
# ### 3. Which columns are numerical?

# %%
file1.select_dtypes(np.number)
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
file1_num = file1._get_numeric_data()
file1_num
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %% [markdown]
# ### 4. Which columns are categorical?

# %%
file1_cat = file1.drop(columns=file1_num.columns)
file1_cat
# Out:
#      customer       state response  coverage education effective_to_date  \
# 0     BU79786  Washington       No     Basic  Bachelor           2/24/11
# 1     QZ44356     Arizona       No  Extended  Bachelor           1/31/11
# 2     AI49188      Nevada       No   Premium  Bachelor           2/19/11
# 3     WW63253  California       No     Basic  Bachelor           1/20/11
# 4     HB64268  Washington       No     Basic  Bachelor            2/3/11
# ...       ...         ...      ...       ...       ...               ...
# 9129  LA72316  California       No     Basic  Bachelor           2/10/11
# 9130  PK87824  California      Yes  Extended   College           2/12/11
# 9131  TD14365  California       No  Extended  Bachelor            2/6/11
# 9132  UP19263  California       No  Extended   College            2/3/11
# 9133  Y167826  California       No  Extended   College           2/14/11
#
#      employmentstatus gender location_code marital_status     policy_type  \
# ...

# %% [markdown]
# ### 5. Check and deal with `NaN` values.

# %%
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer_lifetime_value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective_to_date              9134 non-null   object
#  7   employmentstatus               9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location_code                  9134 non-null   object
#  11  marital_status                 9134 non-null   object
# ...

# %%
nulls_file1 = pd.DataFrame(round(file1.isna().sum()/len(file1),4)*100)
nulls_file1
# Out:
#                                  0
# customer                       0.0
# state                          0.0
# customer_lifetime_value        0.0
# response                       0.0
# coverage                       0.0
# education                      0.0
# effective_to_date              0.0
# employmentstatus               0.0
# gender                         0.0
# income                         0.0
# location_code                  0.0
# marital_status                 0.0
# monthly_premium_auto           0.0
# months_since_last_claim        0.0
# months_since_policy_inception  0.0
# number_of_open_complaints      0.0
# number_of_policies             0.0
# policy_type                    0.0
# policy                         0.0
# renew_offer_type               0.0
# sales_channel                  0.0
# total_claim_amount             0.0
# vehicle_class                  0.0
# vehicle_size                   0.0

# %% [markdown]
# ### 6. Datetime format- Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie Jan Feb and March

# %%
import datetime

# %%
date_file1 = pd.DataFrame(file1, columns = new_columns)
date_file1
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  \
# ...

# %%
date_file1['effective_to_date'] = pd.to_datetime(date_file1['effective_to_date'], errors='coerce')
date_file1.dtypes
# Out:
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                   int64
# months_since_policy_inception             int64
# number_of_open_complaints                 int64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# ...

# %%
date_file1["months"] = pd.DatetimeIndex(date_file1["effective_to_date"]).month
date_file1.shape
# Out:
# (9134, 25)

# %%
date_file1.dtypes
# Out:
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                   int64
# months_since_policy_inception             int64
# number_of_open_complaints                 int64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# ...

# %%
# Check the results another way
date_file1["months"].value_counts()
# Out:
# 1    4898
# 2    4236
# Name: months, dtype: int64

# %%
# filtered - first quarter (January to March)
date_file1.query('months>=1 and months<=3')
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  \
# ...

# %% [markdown]
# ### 7. BONUS: Put all the previously mentioned data transformations into a function.

# %%
def data_cleaning(name, file):
    import numpy as np
    import pandas as pd
    import datetime
    
    # read the file
    name = pd.read_csv(file)
    
    # shape
    print("The shape of the file 1: \n", name.shape, "\n")
    
    # standardize the columns
    new_columns = []
    for i in range(len(name.columns)):
        new_columns.append(name.columns[i].lower().replace(" ","_"))
    
    name.columns = new_columns
    
    print("The new columns of the file 1 are: \n", name.columns, "\n")
    
    # columns - numerical
    name_num = name._get_numeric_data()
    ("\n")
    
    # columns categorical
    name_cat = name.drop(columns=name_num.columns)
    
    # check the Nan-values
    name.info()
    ("\n")
    nulls_name = pd.DataFrame(round(name.isna().sum()/len(name),4)*100)
    
    #Datetime format
    
    date_name = pd.DataFrame(name, columns = new_columns)
    date_name['effective_to_date'] = pd.to_datetime(date_name['effective_to_date'], errors='coerce')
    date_name["months"] = pd.DatetimeIndex(date_name["effective_to_date"]).month
    date_name.query('months>=1 & months<=3')
    
    print("\n The numerical columns: \n", name_num, "\n")
    print("\n The categrical columns: \n", name_cat, "\n")
    print("\n The overview about null-values in the rows: \n", nulls_name, "\n")
    print("The head of the date_file as a query for the first qarter: ")
    print("The new datatypes are: ", date_name.dtypes, "\n")
    print(date_name.query('months>=1 & months<=3'))

# %%
data_cleaning(file1, 'marketing_customer_analysis.csv')

# %% [markdown]
# ## 8. EDA (Exploratory Data Analysis)

# %% [markdown]
# - Show DataFrame info

# %%
date_file1.dtypes
# Out:
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                   int64
# months_since_policy_inception             int64
# number_of_open_complaints                 int64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# ...

# %%
date_file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer_lifetime_value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective_to_date              9134 non-null   datetime64[ns]
#  7   employmentstatus               9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location_code                  9134 non-null   object
#  11  marital_status                 9134 non-null   object
# ...

# %%
date_file1.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income location_code  \
# 0        2011-02-24         Employed      F   56274      Suburban
# 1        2011-01-31       Unemployed      F       0      Suburban
# 2        2011-02-19         Employed      F   48767      Suburban
# 3        2011-01-20       Unemployed      M       0      Suburban
# 4        2011-02-03         Employed      M   43836         Rural
#
#   marital_status  monthly_premium_auto  months_since_last_claim  \
# ...

# %% [markdown]
# - Describe DataFrame

# %%
# describe numerical dates
date_file1.describe(include=[np.number])
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        months_since_last_claim  months_since_policy_inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %%
# describe categorical dates
date_file1.describe(include=[np.object])
# Out:
#        customer       state response coverage education employmentstatus  \
# count      9134        9134     9134     9134      9134             9134
# unique     9134           5        2        3         5                5
# top     AX10148  California       No    Basic  Bachelor         Employed
# freq          1        3150     7826     5568      2748             5698
#
#        gender location_code marital_status    policy_type       policy  \
# count    9134          9134           9134           9134         9134
# unique      2             3              3              3            9
# top         F      Suburban        Married  Personal Auto  Personal L3
# freq     4658          5779           5298           6788         3426
#
#        renew_offer_type sales_channel  vehicle_class vehicle_size
# count              9134          9134           9134         9134
# unique                4             4              6            3
# ...

# %% [markdown]
# - Show a plot of the total number of responses broken down by response kind.

# %%
date_file1["response"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Show a plot of the response rate number of responses by the sales channel.

# %%
date_file1["sales_channel"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Show a plot of the distribution of the total claim amount, broken down by response kind. Try a boxplot and distribution plot, for each response kind. For the distribution plot, try to plot both kinds of responses in one chart (you can try with seaborn's histplot, using the hue parameter).

# %%
# boxplot
sns.boxplot(y='total_claim_amount', x='response', 
                 data=date_file1, 
                 palette="colorblind",)
# Out:
# <AxesSubplot:xlabel='response', ylabel='total_claim_amount'>

# %%
sns.displot(date_file1, x="total_claim_amount", hue="response")

# %% [markdown]
# - Create similar plots like in the task before, but for Income

# %%
# boxplot
sns.boxplot(y='income', x='response', 
                 data=date_file1, 
                 palette="colorblind")
# Out:
# <AxesSubplot:xlabel='response', ylabel='income'>

# %%
sns.displot(date_file1, x="income", hue="response")

# %% [markdown]
# - NEW: Create a scatterplot between total claim amount and income. Play around with the parameters of the scatterplot (markersize? alpha?) and try to identify more features within the data just visually. You can also try different seaborn plots. Check to find suitable ones: https://www.python-graph-gallery.com/134-how-to-avoid-overplotting-with-python

# %%
plt.scatter(x=date_file1['total_claim_amount'], y=date_file1['income'])
plt.show()

# %%
plt.scatter(x=date_file1['total_claim_amount'], y=date_file1['income'], marker=2)
plt.show()

# %%
plt.scatter(x=date_file1['total_claim_amount'], y=date_file1['income'], color="red", marker=4)
plt.show()

# %% [markdown]
# # Customer Analysis Round 4

# %% [markdown]
# Check the data types of the columns. Get the numeric data into dataframe called numerical and categorical columns in a dataframe called categoricals. (You can use np.number and np.object to select the numerical data types and categorical data types respectively)

# %%
date_file1.dtypes
# Out:
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                   int64
# months_since_policy_inception             int64
# number_of_open_complaints                 int64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# ...

# %%
dfnum=date_file1._get_numeric_data()
dfnum.head()
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    number_of_open_complaints  number_of_policies  total_claim_amount  months
# 0                          0                   1          384.811147       2
# 1                          0                   8         1131.464935       1
# ...

# %%
dfobj=date_file1.describe(include=[np.object])
dfobj.head()
# Out:
#        customer       state response coverage education employmentstatus  \
# count      9134        9134     9134     9134      9134             9134
# unique     9134           5        2        3         5                5
# top     AX10148  California       No    Basic  Bachelor         Employed
# freq          1        3150     7826     5568      2748             5698
#
#        gender location_code marital_status    policy_type       policy  \
# count    9134          9134           9134           9134         9134
# unique      2             3              3              3            9
# top         F      Suburban        Married  Personal Auto  Personal L3
# freq     4658          5779           5298           6788         3426
#
#        renew_offer_type sales_channel  vehicle_class vehicle_size
# count              9134          9134           9134         9134
# unique                4             4              6            3
# ...

# %% [markdown]
# Now we will try to check the normality of the numerical variables visually
# - Use seaborn library to construct distribution plots for the numerical variables
# - Use Matplotlib to construct histograms
# - Do the distributions for different numerical variables look like a normal distribution

# %%
dfnum=dfnum.rename(columns={ dfnum.columns[0]: "index"})
dfnum.columns
# Out:
# Index(['index', 'income', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'total_claim_amount', 'months'],
#       dtype='object')

# %%
# create a new subset without the column "months"
dfnum=dfnum.drop(["months"], axis=1)
dfnum.head()
# Out:
#           index  income  monthly_premium_auto  months_since_last_claim  \
# 0   2763.519279   56274                    69                       32
# 1   6979.535903       0                    94                       13
# 2  12887.431650   48767                   108                       18
# 3   7645.861827       0                   106                       18
# 4   2813.692575   43836                    73                       12
#
#    months_since_policy_inception  number_of_open_complaints  \
# 0                              5                          0
# 1                             42                          0
# 2                             38                          0
# 3                             65                          0
# 4                             44                          0
#
#    number_of_policies  total_claim_amount
# 0                   1          384.811147
# 1                   8         1131.464935
# 2                   2          566.472247
# ...

# %%
# Use seaborn library to construct distribution plots for the numerical variables
sns.pairplot(dfnum)

# %%
# Use Matplotlib to construct histograms
dfnum.hist(bins=15, figsize=(15, 6), layout=(2, 4));

# %%
dfnum.columns
# Out:
# Index(['index', 'income', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'total_claim_amount'],
#       dtype='object')

# %% [markdown]
# ### -> There is no numerical variable with a normal distribution

# %%
# Do the distributions for different numerical variables look like a normal distribution
sns.distplot(dfnum['income'],kde = False)
# Out:
# <AxesSubplot:xlabel='income'>

# %%
sns.distplot(dfnum['total_claim_amount'],kde = False)
# Out:
# <AxesSubplot:xlabel='total_claim_amount'>

# %% [markdown]
# For the numerical variables, check the multicollinearity between the features. Please note that we will use the column total_claim_amount later as the target variable.

# %%
sns.boxplot(x="income", y="monthly_premium_auto", data=dfnum)

# %% [markdown]
# Drop one of the two features that show a high correlation between them (greater than 0.9). Write code for both the correlation matrix and for seaborn heatmap. If there is no pair of features that have a high correlation, then do not drop any features

# %%
corr_data = dfnum.drop(['index'], axis=1)
correlations_matrix = corr_data.corr()
correlations_matrix
# Out:
#                                  income  monthly_premium_auto  \
# income                         1.000000             -0.016665
# monthly_premium_auto          -0.016665              1.000000
# months_since_last_claim       -0.026715              0.005026
# months_since_policy_inception -0.000875              0.020257
# number_of_open_complaints      0.006408             -0.013122
# number_of_policies            -0.008656             -0.011233
# total_claim_amount            -0.355254              0.632017
#
#                                months_since_last_claim  \
# income                                       -0.026715
# monthly_premium_auto                          0.005026
# months_since_last_claim                       1.000000
# months_since_policy_inception                -0.042959
# number_of_open_complaints                     0.005354
# number_of_policies                            0.009136
# total_claim_amount                            0.007563
#
# ...

# %%
mask = np.zeros_like(correlations_matrix)
mask[np.triu_indices_from(mask)] = True
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(correlations_matrix, mask=mask, annot=True)
plt.show()

# %% [markdown]
# ### -> There is no feature with a high correlation (> 0,9).
